# %% [markdown]
# # Plotly Assignment

# %%
Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a
scatter plot for age and fare columns in the titanic dataset.

# %%
import plotly.graph_objects as go
import seaborn as sns 
titanic = sns.load_dataset('titanic')

fig = go.Figure()
fig.add_trace(go.Scatter(x =titanic.age, y=titanic.fare , mode ='markers'))

# %% [markdown]
# ![newplot (1).png](attachment:a7b9bab1-b41c-437a-bb1d-d5910121add1.png)

# %%
Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
import plotly.express as px
df = px.data.tips()
fig = px.box(df, y="total_bill")
fig.show()

# %% [markdown]
# ![newplot (2).png](attachment:8b1c4dec-a2b6-4440-b076-2d24aa2b68fa.png)

# %%
Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in
the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day"
column with the color parameter.

# %%
import plotly.express as px
tips = px.data.tips()
fig = px.histogram(tips, x="sex", y="total_bill", color="day", barmode="group", pattern_shape="smoker")
fig.show()

# %% [markdown]
# ![newplot (3).png](attachment:c86c5a67-0b3a-4a7d-b080-b2efa480a6d0.png)

# %%
Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for
the color parameter.

# %%
iris = sns.load_dataset('iris')

# %%
import plotly.express as px
iris = px.data.iris()
fig = px.scatter_matrix(iris, dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"], color="species")
fig.show()

# %% [markdown]
# ![newplot (4).png](attachment:e50af8d7-6d44-4135-98da-28383001f8f4.png)

# %%
Q5. What is Distplot? Using Plotly express, plot a distplot.

# %% [markdown]
# Distplot is a visualization tool that combines a histogram with a kernel density estimate plot to represent the distribution of a continuous variable. It provides a way to visualize the shape, spread, and skewness of the data.

# %% [markdown]
# ![newplot (5).png](attachment:20194cdc-1aae-41f4-b47f-b6eba61f282e.png)
